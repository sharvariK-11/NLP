# %% [markdown]
# <a href="https://colab.research.google.com/github/sharvariK-11/NLP/blob/main/OCR_with_Tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import cv2 
import pytesseract
import matplotlib.pyplot as plt
from IPython.display import Image
from pylab import rcParams
import numpy as np
from pprint import pprint
from pytesseract import Output

# %%
file_name = "/content/drive/MyDrive/ocr.png"
rcParams['figure.figsize'] = 8, 16

# %%
img = cv2.imread(file_name)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
text_out = pytesseract.image_to_string(img)

# %%
text_out
# Out:
# ' \n\n \n\n \n\nSemester fee payment details\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nRoll No: 200020123\n\nTotal amount paid 102950.0\n\nYour transaction id for\n\nfuture reference 182292764770\nSBI Internet\n\nYour mode of payment eee\nCompleted\n\nTransaction status\n\n \n\n \n\nSuccessfully\n\n \n\n \n\n \n\x0c'

# %% [markdown]
# functions:
# 1.image_to_string(read image file) = extracts text from image
# image_to_boxes = returns coordinates of boxes

# %%
d= pytesseract.image_to_data(img, output_type = Output.DICT)

# %%
d.keys()
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %%
d["text"]
# Out:
# ['',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  'Semester',
#  'fee',
#  'payment',
#  'details',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  'Roll',
#  'No:',
#  '200020123',
#  '',
#  '',
#  'Total',
#  'amount',
#  'paid',
#  '102950.0',
#  '',
#  '',
#  'Your',
#  'transaction',
#  'id',
#  'for',
#  '',
#  '',
#  'future',
#  'reference',
#  '182292764770',
#  '',
#  'SBI',
#  'Internet',
#  '',
#  '',
#  'Your',
#  'mode',
#  'of',
#  'payment',
#  'eee',
#  '',
#  'Completed',
#  '',
#  '',
#  '',
#  'Transaction',
#  'status',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
# ...
